# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  LinearRegression, Lasso, Ridge
from sklearn.metrics import  mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset.csv")
df.sample(5)
# Out:
#            f1        f2        f3        f4        f5        f6        f7  \
# 127  2.076748 -1.556582  0.543600  0.732640 -0.625563  0.051946 -0.037222
# 26  -1.222895 -0.831955 -0.113128  1.259233 -0.531455 -1.479444  0.604121
# 69  -0.525755  0.872321  0.322719  1.179440  0.310908  1.831459  0.491919
# 117  1.911419 -0.846851  0.900399 -0.172802  0.185176  1.058729  2.868403
# 99   0.876456  1.170199  1.186735 -1.207022  0.603248  0.338023 -2.487809
#
#            f8        f9       f10  ...      f142      f143      f144  \
# 127 -0.550305  0.381935 -1.739714  ...  1.748136  1.682648 -0.342245
# 26  -1.840078  0.071254  1.194592  ... -0.244080 -0.039307 -0.134497
# 69  -0.019016 -0.759133  0.401712  ...  0.962345  0.945888  1.073622
# 117 -0.952316 -1.280456  1.523239  ...  1.505196  1.575720  0.018791
# 99   0.367620 -1.561493  1.172757  ...  0.191451  0.662169 -1.498635
#
#          f145      f146      f147      f148      f149      f150      target
# 127  2.503238  0.024480 -0.962669 -0.633640 -2.256725  1.607019   28.789768
# 26   0.333860  1.431367  1.081767 -1.312219  0.622070  1.328933 -196.523103
# 69  -0.630846 -0.297867  0.769032 -0.527389 -0.005107  0.398764  -52.043950
# 117  1.322926 -0.551675 -1.866246 -0.760284  1.729301 -1.491080   72.300617
# 99   1.194214  1.301102 -1.998345 -0.705317  0.495766  0.644388  125.035307
#
# [5 rows x 151 columns]

# %%
df.isna().any().any(), x.shape
# Out:
# (np.False_, (200, 150))

# %%
X = df.drop(["target"], axis=1) # by drop All columns will be assigned in x except "target"
y = df["target"]
X.shape, y.shape
# Out:
# ((200, 150), (200,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=.25)
lm = LinearRegression()
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lm.score(X_test, y_test)
# Out:
# 0.7410183335246971

# %%
lasso_model = Lasso(alpha=1)
lasso_model.fit(X_train, y_train)
lasso_model.score(X_test, y_test)
# Out:
# 0.9901476660336155

# %%
ridge_model = Ridge(alpha=1)
ridge_model.fit(X_train, y_train)
ridge_model.score(X_test, y_test)
# Out:
# 0.9462671341742043

# %%
lm.coef_, lm.intercept_
# Out:
# (array([ 30.5502605 , -37.91397171,  14.17527214,   0.78083357,
#           3.75133524, -31.13869527,  53.68852306,  93.56466317,
#         -31.5825238 , -11.38841381, -35.6784998 ,  40.67375848,
#           3.62031964,  -2.09903202, -15.31981974,   6.6902648 ,
#          20.24051312, -17.5043733 ,  42.82135882,  66.27388457,
#         -39.58548175,   5.94205081,  46.0650318 ,  31.54007432,
#          -2.44446922,  -4.2212642 ,   0.59286811,   3.92334798,
#          -5.01154922,   3.93937364,   3.92330605,  -7.34764566,
#          86.817593  ,   0.41148934,  -3.2867563 ,  -3.07684278,
#           4.37177689,   5.2605021 ,  -3.52721952,   9.17214331,
#           6.12833853,   5.46983655,  -0.86360751,  -0.73634359,
#          -3.0067608 ,  -1.31766726,  -5.37890201,   3.1123997 ,
#          -1.04391302,   1.61670639, -28.23622443,  38.83799572,
#           9.38775063,  -2.67626335,  26.0003329 ,  23.04033092,
#         -54.04279193, -28.21843994,  19.08259729,  13.25052065,
#          21.28068869, -39.44894727, -11.08479556,  -3.94083092,
#          12.5233143 ,  -5.29621333,  12.93649639,  18.16838045,
#         -40.99700089,   1.86484489,  29.52465395,  -0.60875437,
#         -47.56273995, -21.16797354,  -2.72626249,   5.81368678,
#          -3.04104575,   0.87317534,  -0.73794143,  -1.87363815,
#           2.40207155,  -3.77087696,   0.64215438,   7.01155184,
#           1.83944806,   2.57685475,  10.83476007,   2.72537537,
#           7.8144321 ,   3.82879094,   5.15895348,   8.13977779,
#          -2.47066721,   7.91221401,  -2.30336063,   8.4234507 ,
#           6.32545984,   1.594731  , -10.2580694 ,   0.30848489,
#           0.50461854,   2.76952208,   2.19633993,   1.44952423,
#           4.66079026,   1.53707697,   3.46664606, -10.09182367,
#           3.85832303,   3.51863836,   1.10276581,  -3.43593973,
#          13.3620698 ,  -3.23612976,   0.59743475, -10.75961705,
#          -0.51764458,  -1.11988028,  -2.58909455,  -7.76642975,
#          -0.78398778,   0.83854905,   7.43261421,   8.11037895,
#          -4.31998527,   3.18740428,  -4.22708942,  -1.3279312 ,
#           0.72960122,  -9.58956299,  -3.11293898, -13.27084129,
#           2.4186831 ,  -7.64790173,  -1.4410984 ,   5.09992737,
#          -2.40476917,  -5.03742364,  -4.89445049,  -0.5978738 ,
#          -2.11188224,  -2.80527747,  -5.47739367,  -4.79262174,
#           6.81555319,  -7.49020894,  -5.10332914,   1.4213112 ,
#           8.2619979 ,  -9.67458169]),
#  np.float64(-3.1531141806649874))

# %%
lasso_model.coef_, lasso_model.intercept_
# Out:
# (array([-0.00000000e+00, -2.44412330e-01,  1.97252435e+01,  0.00000000e+00,
#          3.08713932e+01,  0.00000000e+00,  0.00000000e+00,  5.77703222e+01,
#         -7.94713931e-02,  0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          3.18993512e+01, -0.00000000e+00,  6.25100957e+00,  7.55194924e+01,
#         -0.00000000e+00,  7.98983405e+00,  0.00000000e+00,  7.48130970e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00, -2.36105000e-01,
#          7.35506860e+01, -0.00000000e+00, -0.00000000e+00,  3.03345241e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -5.96641418e-01, -0.00000000e+00,  7.18814788e-01,  0.00000000e+00,
#          2.49000405e-01,  2.30764916e-01, -0.00000000e+00, -0.00000000e+00,
#         -5.67191297e-01,  0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          7.74812026e+00,  0.00000000e+00,  0.00000000e+00,  6.50440152e-01,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -7.91539275e-01, -1.84435449e-01,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,  6.48153862e-01,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  2.88359296e-01,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -1.12921137e+00,  0.00000000e+00,  0.00000000e+00,
#          4.38168550e-01,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -5.76180007e-01,  0.00000000e+00, -0.00000000e+00,  1.53406439e-01,
#          0.00000000e+00, -1.88501791e-01,  0.00000000e+00,  0.00000000e+00,
#          7.76754895e-02, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -1.32780748e-01,  0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -1.15579854e-01, -0.00000000e+00,  0.00000000e+00,
#         -4.42544029e-01, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  2.62289235e-01, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -6.94264331e-02, -0.00000000e+00,  0.00000000e+00,
#         -3.48339893e-01, -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -1.22799795e-01, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00]),
#  np.float64(0.40750894954108396))
