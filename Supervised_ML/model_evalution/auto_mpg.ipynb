# %%
import pandas as pd

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"

column_names = [
    "mpg",
    "cylinders",
    "displacement",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "origin",
    "car_name"
]

df = pd.read_csv(url,
                 sep=r"\s+",# regex for one or more spaces
                 header=None,
                 na_values="?" ,
                 names=column_names,
                 comment="\t")

df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model_year  origin                   car_name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# car_name        0
# dtype: int64

# %%
df.horsepower.describe()
# Out:
# count    392.000000
# mean     104.469388
# std       38.491160
# min       46.000000
# 25%       75.000000
# 50%       93.500000
# 75%      126.000000
# max      230.000000
# Name: horsepower, dtype: float64

# %%
df.loc[:, "horsepower"] = df["horsepower"].fillna(df["horsepower"].mean())

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# car_name        0
# dtype: int64

# %%
features = ["cylinders","displacement","horsepower","weight","acceleration","model_year","origin"]

# %%
x = df[features]
y = df["mpg"]

# %%
x.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0          8         307.0       130.0  3504.0          12.0          70
# 1          8         350.0       165.0  3693.0          11.5          70
# 2          8         318.0       150.0  3436.0          11.0          70
# 3          8         304.0       150.0  3433.0          12.0          70
# 4          8         302.0       140.0  3449.0          10.5          70
#
#    origin
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
y.head()
# Out:
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# Name: mpg, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x.shape, y.shape
# Out:
# ((398, 7), (398,))

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42) #Random state is a random any number to keep the output always same

# %%
x_train.shape, x_test.shape
# Out:
# ((318, 7), (80, 7))

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred[:5]
# Out:
# array([32.86345735, 29.58130242, 21.35126058, 16.80568721, 12.50136229])

# %%
y_test[:5]
# Out:
# 198    33.0
# 396    28.0
# 33     19.0
# 208    13.0
# 93     14.0
# Name: mpg, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 8.195452104073784

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8475731044779434

# %%
model.score(x_test, y_test)
# Out:
# 0.8475731044779434
