# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler

# %%
n_samples = 1500
X, y = datasets.make_circles(n_samples=n_samples, factor=.5, noise=.05, random_state=0)

# %%
plt.figure(figsize=(6, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap="tab10")
plt.title("Clastering Clustering")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %% [markdown]
# ## Implement KMeans Cluster in that

# %%
from sklearn.cluster import KMeans
km = KMeans(n_clusters=2, random_state=0)
km.fit(X)
km.labels_
# Out:
# array([0, 1, 1, ..., 0, 1, 1], shape=(1500,), dtype=int32)

# %%
plt.scatter(X[:, 0], X[:, 1], c=km.labels_, cmap="tab10", edgecolors="k")
