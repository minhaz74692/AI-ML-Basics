# %%
import pandas as pd

from Analytics.Pandas_practice.pandas_data_frame import df_new

# %%
df = pd.read_csv("heights.csv")

# %%
df.describe()
# Out:
#             height
# count  1000.000000
# mean      5.609440
# std       0.327504
# min       4.650000
# 25%       5.360000
# 50%       5.620000
# 75%       5.850000
# max       6.630000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(df.height)
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
mean = df.height.mean()
std = df.height.std()

# %%
df["z_score"] = (df.height - mean )/std

# %%
df.head()
# Out:
#        name  height   z_score
# 0     Aarav    5.45 -0.486834
# 1   Deepika    5.61  0.001710
# 2  Abhishek    5.65  0.123846
# 3     Sneha    5.52 -0.273096
# 4     Kriti    5.69  0.245982

# %%
sns.histplot(df["z_score"])
# Out:
# <Axes: xlabel='z_score', ylabel='Count'>
