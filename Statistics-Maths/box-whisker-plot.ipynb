# %%
import pandas as pd

# %%
df = pd.read_excel("csv-excel-files/math_scores.xlsx", sheet_name="scores")

# %%
df
# Out:
#                     Name  MathScore
# 0                 Fatima      23.00
# 1                  Surya      33.00
# 2                  Aarav      45.00
# 3               Norberto      45.00
# 4                 Ananya      54.00
# 5                Jessica      67.00
# 6                  Maria      68.00
# 7               Priyanka      78.00
# 8                  Abdul      89.00
# 9                  Kiran      91.00
# 10                   NaN        NaN
# 11  25th Percentile (Q1)      42.00
# 12  50th Percentile (Q2)      60.50
# 13  75th Percentile (Q3)      80.75

# %%
df.fillna(df["MathScore"].median(), inplace=True)

# %%
df
# Out:
#                     Name  MathScore
# 0                 Fatima      23.00
# 1                  Surya      33.00
# 2                  Aarav      45.00
# 3               Norberto      45.00
# 4                 Ananya      54.00
# 5                Jessica      67.00
# 6                  Maria      68.00
# 7               Priyanka      78.00
# 8                  Abdul      89.00
# 9                  Kiran      91.00
# 10                  60.5      60.50
# 11  25th Percentile (Q1)      42.00
# 12  50th Percentile (Q2)      60.50
# 13  75th Percentile (Q3)      80.75

# %%
df["MathScore"].quantile( [.75])
# Out:
# 0.75    75.5
# Name: MathScore, dtype: float64

# %%
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df
plt.figure()
plt.boxplot(df['MathScore'])
plt.ylabel('MathScore')
plt.title('Box and Whisker Plot of MathScore')
plt.show()
